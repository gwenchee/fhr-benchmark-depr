# %%
import matplotlib.pyplot as plt

# %%
# z-thickness vs. run time 
trisos = [1, 3, 5, 9, 17, 25, 35 ,101]
time = [8.7990e+02, 6.2276e+02, 5.6407e+02, 5.2286e+02, 5.0227e+02,4.9525e+02, 4.9263e+02, 4.8274e+02]
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(trisos, time,'*')
ax.grid()
ax.set_xlabel('Z-axis thickness [no. of Triso particles]')
ax.set_ylabel('Total time elapsed')
#ax.set_title('Cumulative mass of spent fuel vs. discharge year')
#plt.savefig('figures/cumulative_mass_spent_fuel.png', dpi=300)
# Out:
# Text(0, 0.5, 'Total time elapsed')

# %% [markdown]
# # Conclusion
# For each of these simulations, no. of active and inactive cycles and no. of particles are kept constant.
#
# Reflection Calculation is more expensive than transport calculation, therefore, for a thicker z-axis, the simulation runs faster.
# However, a plateau is reached at approximately z-axis thickness of 30 triso particles. I also ran it for 101 triso particles, and
# runtime decreased. However, it is no longer substantial
#
# Therefore, from now on, all simulations will be run with z-thickness of 101 triso particles.
# z-thickness = triso_pitch*101
